# %%
#import ollama
from langchain_community.llms import Ollama

# %%
# initialize ollama model
m = Ollama(model='tinyllama')

# generate the text with model
response = m.generate(["when did india got its independence?"])

print(response)
# Out:
# /var/folders/dz/qr8lbzs568b3m37bzckypts80000gn/T/ipykernel_45922/1572740293.py:2: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaLLM``.
#   m = Ollama(model='tinyllama')
# generations=[[GenerationChunk(text='India gained its independence on August 15, 1947, from the United Kingdom. The British colonial administration in India had declared Dominion Status for India and Pakistan on May 15, 1937. The Indian independence movement, led by Mahatma Gandhi, began in 1916 with the Salt Satyagraha (Salt March) protests to end British salt taxes.', generation_info={'model': 'tinyllama', 'created_at': '2025-11-02T22:35:16.519782Z', 'response': '', 'done': True, 'done_reason': 'stop', 'context': [529, 29989, 5205, 29989, 29958, 13, 3492, 526, 263, 8444, 319, 29902, 20255, 29889, 2, 29871, 13, 29966, 29989, 1792, 29989, 29958, 13, 8256, 1258, 1399, 423, 2355, 967, 21820, 29973, 2, 29871, 13, 29966, 29989, 465, 22137, 29989, 29958, 13, 2568, 423, 17515, 967, 21820, 373, 3111, 29871, 29896, 29945, 29892, 29871, 29896, 29929, 29946, 29955, 29892, 515, 278, 3303, 12626, 29889, 450, 4908, 25539, 17517, 297, 7513, 750, 8052, 13298, 291, 16034, 363, 7513, 322, 21215, 373, 2610, 29871, 29896, 29945, 29892, 29871, 29896, 29929, 29941, 29955, 29889, 450, 7560, 21820, 10298, 29892, 5331, 491, 10082, 271, 655, 28572, 2918, 29892, 4689, 297, 29871, 29896, 29929, 29896, 29953, 411, 278, 27903, 12178, 3761, 3874, 2350, 313, 20392, 29873, 4779, 29897, 10021, 29879, 304, 1095, 4908, 15795, 8818, 267, 29889], 'total_duration': 1615691042, 'load_duration': 651494583, 'prompt_eval_count': 42, 'prompt_eval_duration': 140742792, 'eval_count': 92, 'eval_duration': 809009205})]] llm_output=None run=[RunInfo(run_id=UUID('32b9a8dc-208a-486c-a26c-6b615c226801'))] type='LLMResult'

# %%
response.generations[0][0].text
# Out:
# 'India gained its independence on August 15, 1947, from the United Kingdom. The British colonial administration in India had declared Dominion Status for India and Pakistan on May 15, 1937. The Indian independence movement, led by Mahatma Gandhi, began in 1916 with the Salt Satyagraha (Salt March) protests to end British salt taxes.'

# %%
response = m.generate(["how did india got its independence in 2025?"])

print(response.generations[0][0].text)
# Out:
# India is scheduled to gain independence from British rule on December 15, 2025, which means that the country will turn 73 years old at that time. The current calendar year (2024) ends on December 31, and in 2025, India would have become a republic on January 26, 2025. This date marks the end of British rule in India and the beginning of Indian independence.
